# %% [markdown]
# <a href="https://colab.research.google.com/github/urgsidata/pytorch-tutor1/blob/main/Pytorch1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Tutorial PyTorch")
# Out:
# Tutorial PyTorch

# %%
a=10
b=40
c=a*b
print("jumlah = ",c)
# Out:
# jumlah =  400
